# %%
import pandas as pd
import matplotlib.pyplot as plt
import os 
import datetime 
import tweepy
import json 
import glob

# %%
pd.set_option('display.max_rows',100)

# %%
# set to main directory 
os.chdir('/Users/ishitagopal/Box/Projects/state_covid_policy')

# %%
metadata_file_names = glob.glob('Data/*/*_metadata_*.csv')

# %%
# read all files 
li =[]
for file in metadata_file_names:
    df = pd.read_csv(file, header = None, index_col=None)
    df['state'] = file.split('/')[1]
    li.append(df)

# %%
frame = pd.read_csv('Data/Alabama/Alabama_metadata_June08.csv', header = None)

# %%
frame[frame[5]>100]
# Out:
#                   0            1           2             3       4      5  \
# 70    GregReed21234  929609108.0  2020-06-08  1.270077e+18  3186.0  150.0
# 94  205JackWilliams   21784607.0  2020-06-08  1.270089e+18  3209.0  134.0
#
#              6       7
# 70  2012-11-06  active
# 94  2009-02-24  active

# %%
frame = pd.read_csv('Data/Alabama/Alabama_metadata_June08.csv', header = None)
l = frame[frame[5]>100][3].to_list()

# %%
frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.columns = ['index', 'screen_name','account_id','date_scraped',
                 'latest_tweet_id','total_tweets','last_week_total_tweets',
                 'active_since','active','state']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-bdd8425a4dae> in <module>
#       1 frame.columns = ['index', 'screen_name','account_id','date_scraped',
#       2                  'latest_tweet_id','total_tweets','last_week_total_tweets',
# ----> 3                  'active_since','active','state']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# ...

# %%
# Select active accounts
frame = frame.loc[frame.last_week_total_tweets.isnull()==False,:]

# %%
frame[frame.state == 'Alabama']
# Out:
#         screen_name   account_id date_scraped latest_tweet_id total_tweets  \
# 2       andy_whitt1  2.87325e+09   2020-06-08     1.26943e+18          347
# 3     PronceyHouse7  1.08989e+09   2020-06-08     1.26985e+18         2754
# 4   RepTerriCollins  4.74388e+08   2020-06-08      1.2686e+18          767
# 5   ScottStadthagen  8.34245e+17   2020-06-08     1.26292e+18          538
# 7    RandyPriceSD13  9.61103e+17   2020-06-08     1.26694e+18          154
# 8         reprowe13  3.04933e+09   2020-06-08     1.26165e+18          773
# 9    RepAllenFarley  4.76135e+08   2020-06-08     1.26961e+18         3191
# 10       RepSouth16  1.39027e+09   2020-06-08     1.26721e+18          346
# 11     bytracyestes  8.14992e+17   2020-06-08     1.25924e+18          522
# 12        jamiekiel  4.31397e+07   2020-06-08     1.26244e+18          531
# 14    RexReynolds01  1.53462e+09   2020-06-08     1.26894e+18          255
# ...

# %%
frame.last_week_total_tweets.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e463e7e17215> in <module>
# ----> 1 frame.last_week_total_tweets.astype(int)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
high_frequency = frame.loc[frame.last_week_total_tweets > 100,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-21058250fce1> in <module>
# ----> 1 high_frequency = frame.loc[frame.last_week_total_tweets > 100,:]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
high_frequency[1,]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b41b30599e1b> in <module>
# ----> 1 high_frequency[1,]
#
# NameError: name 'high_frequency' is not defined

# %%
# 6 people are tweeting more than 200 times a week 
# 32 people are tweeting more than 100 times a week

# %%
3200/100
# Out:
# 32.0

# %%
16.0*7
# Out:
# 112.0

# %%
200+200+200+200
# Out:
# 800
