# %%
import pandas as pd
import os 
import datetime 
import tweepy
import json 
import glob

# %%
pd.set_option('display.max_rows',100)

# %%
# Navigate to where code files are and import helper functions
os.chdir('/Users/ishitagopal/Box/Projects/state_covid_policy/code')
# %run twitter_api_helper_functions.ipynb

# %%
# Function for navigating to the state folder --- Will have to be set
# Assumes state directory already exists 
def cd(state):
    os.chdir('/Users/ishitagopal/Box/Projects/state_covid_policy/Data/%s' % state)

# %%
# Input state name for which tweets, followers and friends have to be collected 
state_name = 'Texas'

# change folder to State's folder
cd(state_name)

# check path if path was correctly assigned 
os.getcwd()
# Out:
# '/Users/ishitagopal/Box/Projects/state_covid_policy/Data/Texas'

# %%
# Import handles collected by Taegyoon 
twitter_handles = glob.glob('*state_legislators_handle*.csv')[0]
print(twitter_handles)

df = pd.read_csv(twitter_handles)
df
# Out:
# state_legislators_handle_tx.csv
#      state chamber party               name        handle_1 handle_2  \
# 0    Texas       H   (R)     Gary VanDeaver   GaryVanDeaver      NaN
# 1    Texas       H   (R)          Dan Flynn       Dan_Flynn      NaN
# 2    Texas       H   (R)     Cecil Bell Jr.         CBellJr      NaN
# 3    Texas       H   (R)         Keith Bell             NaN      NaN
# 4    Texas       H   (R)        Cole Hefner    ColeHefnerTX      NaN
# ..     ...     ...   ...                ...             ...      ...
# 176  Texas       S   (D)    Eddie Lucio Jr.    SenatorLucio      NaN
# 177  Texas       S   (R)      Charles Perry    electcharles      NaN
# 178  Texas       S   (D)  Jose R. Rodriguez    JoseforTexas      NaN
# 179  Texas       S   (R)         Pat Fallon  FallonForTexas      NaN
# 180  Texas       S   (R)        Kel Seliger        kseliger      NaN
#
#                                               source_1  source_2  note  \
# 0                                                 cook       NaN   NaN
# 1    https://www.google.com/search?client=safari&rl...       NaN   NaN
# 2    https://www.google.com/search?client=safari&rl...       NaN   NaN
# 3                                                  NaN       NaN   NaN
# 4    https://www.google.com/search?client=safari&rl...       NaN   NaN
# ..                                                 ...       ...   ...
# 176  https://www.google.com/search?client=safari&rl...       NaN   NaN
# 177  https://www.google.com/search?client=safari&rl...       NaN   NaN
# 178  https://www.google.com/search?client=safari&rl...       NaN   NaN
# 179                                               cook       NaN   NaN
# 180                                               cook       NaN   NaN
#
#      Unnamed: 9
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 176         NaN
# 177         NaN
# 178         NaN
# 179         NaN
# 180         NaN
#
# [181 rows x 10 columns]

# %%
# selct non null handles 
handles_1 = df.loc[df.handle_1.isnull()==False, 'handle_1']
# reset index 
handles_1 = handles_1.reset_index(drop = True)

handles_1.head()
# Out:
# 0      GaryVanDeaver
# 1          Dan_Flynn
# 2            CBellJr
# 3       ColeHefnerTX
# 4    RepMattSchaefer
# Name: handle_1, dtype: object

# %%
# check number of handles 
len(handles_1)
# Out:
# 176

# %%
# run get_timeline() function to collect all tweets  
i = 0
for handle in handles_1:
    print(handle)
    print('account %s' %i)
    
    get_timeline(handle, state_name)
    
    i+=1
# Out:
# JoelMFerry
# account 0
# not protected
# getting tweets before 974641981166096383
# ...38 tweets downloaded so far
# writen to file
# JeffersonMoss
# account 1
# not protected
# getting tweets before 907189195
# ...189 tweets downloaded so far
# writen to file
# vpottercache
# account 2
# not protected
# getting tweets before 519579036062732287
# ...58 tweets downloaded so far
# writen to file
# djohnsonhouse4
# account 3
# not protected
# getting tweets before 1000045059860058111
# ...376 tweets downloaded so far
# getting tweets before 952399006864257028
# ...376 tweets downloaded so far
# writen to file
# cory_maloy
# account 4
# not protected
# getting tweets before 879893118895529983
# ...399 tweets downloaded so far
# getting tweets before 230347072585490432
# ...599 tweets downloaded so far
# getting tweets before 11111919850
# ...772 tweets downloaded so far
# getting tweets before 2363131725
# ...772 tweets downloaded so far
# writen to file
# WaldripSteve
# account 5
# not protected
# getting tweets before 953658190821965823
# ...9 tweets downloaded so far
# writen to file
# KellyMiles4Utah
# account 6
# not protected
# getting tweets before 716808623993659392
# ...116 tweets downloaded so far
# writen to file
# MikeSchultz_12
# account 7
# not protected
# account inactive
# Paul_Ray
# account 8
# not protected
# getting tweets before 1185974344343867392
# ...397 tweets downloaded so far
# getting tweets before 1072595649877737471
# ...596 tweets downloaded so far
# getting tweets before 1004438349011128321
# ...793 tweets downloaded so far
# getting tweets before 905173332458430463
# ...986 tweets downloaded so far
# getting tweets before 863759595730337791
# ...1183 tweets downloaded so far
# getting tweets before 808792495752613887
# ...1377 tweets downloaded so far
# getting tweets before 748920856827555839
# ...1574 tweets downloaded so far
# getting tweets before 694280500907773951
# ...1772 tweets downloaded so far
# getting tweets before 643137384087994367
# ...1969 tweets downloaded so far
# getting tweets before 592801003143069695
# ...2165 tweets downloaded so far
# getting tweets before 565225759980421119
# ...2363 tweets downloaded so far
# getting tweets before 543179439950286847
# ...2562 tweets downloaded so far
# getting tweets before 528856373556432895
# ...2761 tweets downloaded so far
# getting tweets before 515113404034732031
# ...2960 tweets downloaded so far
# getting tweets before 502457105472057343
# ...3160 tweets downloaded so far
# getting tweets before 488438011886338048
# ...3206 tweets downloaded so far
# getting tweets before 486618898813706239
# ...3206 tweets downloaded so far
# writen to file
# bwilson2969
# account 9
# not protected
# account inactive
# StephenHandyUT
# account 10
# not protected
# getting tweets before 1234902879506272255
# ...400 tweets downloaded so far
# getting tweets before 1067799757735702527
# ...600 tweets downloaded so far
# getting tweets before 960976660467089407
# ...800 tweets downloaded so far
# getting tweets before 785690347997245439
# ...1000 tweets downloaded so far
# getting tweets before 714280228676239360
# ...1198 tweets downloaded so far
# getting tweets before 657782328320724992
# ...1397 tweets downloaded so far
# getting tweets before 573269465435013119
# ...1597 tweets downloaded so far
# getting tweets before 564890032343748607
# ...1797 tweets downloaded so far
# getting tweets before 395579676279586815
# ...1907 tweets downloaded so far
# getting tweets before 192687898989051904
# ...1907 tweets downloaded so far
# writen to file
# RepBarlow
# account 11
# not protected
# account inactive
# timothyhawkes
# account 12
# not protected
# getting tweets before 530753263692677120
# ...178 tweets downloaded so far
# writen to file
# raywardutah
# account 13
# not protected
# getting tweets before 457007414240223231
# ...39 tweets downloaded so far
# writen to file
# dougsagers
# account 14
# not protected
# account inactive
# SueDuckworthUT
# account 15
# not protected
# getting tweets before 825033647354900479
# ...55 tweets downloaded so far
# writen to file
# electsandrah
# account 16
# not protected
# account inactive
# jenforutah
# account 17
# not protected
# getting tweets before 1247381797047918591
# ...400 tweets downloaded so far
# getting tweets before 1218021297361281025
# ...600 tweets downloaded so far
# getting tweets before 991476477366493183
# ...661 tweets downloaded so far
# getting tweets before 849651438108065791
# ...661 tweets downloaded so far
# writen to file
# RepBriscoe
# account 18
# not protected
# getting tweets before 1205328545611841540
# ...400 tweets downloaded so far
# getting tweets before 1101141112033427455
# ...600 tweets downloaded so far
# getting tweets before 1007264554156343296
# ...800 tweets downloaded so far
# getting tweets before 963494597702766591
# ...1000 tweets downloaded so far
# getting tweets before 951537962109448191
# ...1200 tweets downloaded so far
# getting tweets before 877882289169981439
# ...1400 tweets downloaded so far
# getting tweets before 839282900029693951
# ...1600 tweets downloaded so far
# getting tweets before 828805065662091263
# ...1800 tweets downloaded so far
# getting tweets before 816844096740282367
# ...2000 tweets downloaded so far
# getting tweets before 778641940937969663
# ...2200 tweets downloaded so far
# getting tweets before 705935597668446207
# ...2400 tweets downloaded so far
# getting tweets before 673906858348818431
# ...2600 tweets downloaded so far
# getting tweets before 637686067215204352
# ...2800 tweets downloaded so far
# getting tweets before 527118413400141824
# ...3000 tweets downloaded so far
# getting tweets before 441284035126382592
# ...3200 tweets downloaded so far
# getting tweets before 435835453074190335
# ...3248 tweets downloaded so far
# getting tweets before 433300074857107456
# ...3248 tweets downloaded so far
# writen to file
# RepAngelaRomero
# account 19
# not protected
# getting tweets before 1272224161742516224
# ...398 tweets downloaded so far
# getting tweets before 1255866253815627775
# ...598 tweets downloaded so far
# getting tweets before 1241411690513588224
# ...798 tweets downloaded so far
# getting tweets before 1226678740467372033
# ...998 tweets downloaded so far
# getting tweets before 1215288111715930111
# ...1198 tweets downloaded so far
# getting tweets before 1189169219977412608
# ...1397 tweets downloaded so far
# getting tweets before 1168622593055707135
# ...1596 tweets downloaded so far
# getting tweets before 1149885013178978303
# ...1796 tweets downloaded so far
# getting tweets before 1135376266205442047
# ...1995 tweets downloaded so far
# getting tweets before 1116693286146547712
# ...2195 tweets downloaded so far
# getting tweets before 1105650537330954239
# ...2394 tweets downloaded so far
# getting tweets before 1089965549314949119
# ...2593 tweets downloaded so far
# getting tweets before 1070125019634618367
# ...2792 tweets downloaded so far
# getting tweets before 1048960485310095359
# ...2992 tweets downloaded so far
# getting tweets before 1027247134741950463
# ...3191 tweets downloaded so far
# getting tweets before 1002273247805587455
# ...3228 tweets downloaded so far
# getting tweets before 996908801558114303
# ...3228 tweets downloaded so far
# writen to file
# RepBrianKing
# account 20
# not protected
# getting tweets before 1283498792390541312
# ...400 tweets downloaded so far
# getting tweets before 1275626512989843457
# getting tweets before 967219584209010689
# ...2993 tweets downloaded so far
# getting tweets before 926204650809733119
# ...3193 tweets downloaded so far
# getting tweets before 851554216870989824
# ...3243 tweets downloaded so far
# getting tweets before 832269733290401791
# ...3243 tweets downloaded so far
# writen to file
# RepMarkwheatley
# account 27
# not protected
# getting tweets before 1032787477700861951
# ...400 tweets downloaded so far
# getting tweets before 831657662416723967
# ...592 tweets downloaded so far
# getting tweets before 632951224053035011
# ...792 tweets downloaded so far
# getting tweets before 370235011921768447
# ...863 tweets downloaded so far
# getting tweets before 293796893744566271
# ...863 tweets downloaded so far
# writen to file
# RepPatriceArent
# account 28
# not protected
# getting tweets before 1222228774957174783
# ...400 tweets downloaded so far
# getting tweets before 1045361719327907839
# ...600 tweets downloaded so far
# getting tweets before 773861349776510975
# ...799 tweets downloaded so far
# getting tweets before 609536419346780159
# ...998 tweets downloaded so far
# getting tweets before 402780704980754431
# ...1162 tweets downloaded so far
# getting tweets before 159041445381156863
# ...1162 tweets downloaded so far
# writen to file
# RepCarolMoss
# account 29
# not protected
# getting tweets before 1283630938132340735
# ...398 tweets downloaded so far
# getting tweets before 1278914555767222271
# ...598 tweets downloaded so far
# getting tweets before 1268541704287764486
# ...796 tweets downloaded so far
# getting tweets before 1263334803195047935
# ...995 tweets downloaded so far
# getting tweets before 1257837334952685567
# ...1194 tweets downloaded so far
# getting tweets before 1252824062486700031
# ...1393 tweets downloaded so far
# getting tweets before 1245567091270246404
# ...1593 tweets downloaded so far
# getting tweets before 1240298419807072255
# ...1793 tweets downloaded so far
# getting tweets before 1226007487356137472
# ...1993 tweets downloaded so far
# getting tweets before 1214571117790158847
# ...2193 tweets downloaded so far
# getting tweets before 1204261285325459456
# ...2392 tweets downloaded so far
# getting tweets before 1197751157189251071
# ...2591 tweets downloaded so far
# getting tweets before 1192858370283171839
# ...2791 tweets downloaded so far
# getting tweets before 1186498147897360384
# ...2989 tweets downloaded so far
# getting tweets before 1180949565995769855
# ...3188 tweets downloaded so far
# getting tweets before 1172737640451362815
# ...3229 tweets downloaded so far
# getting tweets before 1172009592936685568
# ...3229 tweets downloaded so far
# writen to file
# erickhutchings
# account 30
# not protected
# getting tweets before 791757706960908287
# ...85 tweets downloaded so far
# writen to file
# RepJimDunnigan
# account 31
# not protected
# getting tweets before 791030355004231679
# ...289 tweets downloaded so far
# getting tweets before 735982056774066176
# ...289 tweets downloaded so far
# writen to file
# steph_pitcher
# account 32
# not protected
# getting tweets before 39236751708917760
# ...186 tweets downloaded so far
# writen to file
# KimColeman4Ut42
# account 33
# not protected
# account inactive
# writerathome
# account 34
# not protected
# getting tweets before 406695072038526975
# ...153 tweets downloaded so far
# writen to file
# RepAStoddard
# account 35
# not protected
# getting tweets before 1280594392571502592
# ...400 tweets downloaded so far
# getting tweets before 1269495770048159743
# ...599 tweets downloaded so far
# getting tweets before 1260591672682876927
# ...799 tweets downloaded so far
# getting tweets before 1253437700943708159
# getting tweets before 438712111347167231
# ...1798 tweets downloaded so far
# getting tweets before 428273362075254783
# ...1998 tweets downloaded so far
# getting tweets before 412991737355722751
# ...2198 tweets downloaded so far
# getting tweets before 374312568334352383
# ...2398 tweets downloaded so far
# getting tweets before 335423785241047040
# ...2598 tweets downloaded so far
# getting tweets before 218428453949669375
# ...2798 tweets downloaded so far
# getting tweets before 1809521080
# ...2801 tweets downloaded so far
# getting tweets before 1285629903
# ...2801 tweets downloaded so far
# writen to file
# CandicePierucci
# account 42
# not protected
# getting tweets before 1242469599532072967
# ...400 tweets downloaded so far
# getting tweets before 1213190888379125759
# ...600 tweets downloaded so far
# getting tweets before 1156771125281427456
# ...800 tweets downloaded so far
# getting tweets before 1095940358549135359
# ...1000 tweets downloaded so far
# getting tweets before 1011825310390579199
# ...1197 tweets downloaded so far
# getting tweets before 981971789109579775
# ...1396 tweets downloaded so far
# getting tweets before 966031949922844671
# ...1594 tweets downloaded so far
# getting tweets before 956650979994185727
# ...1792 tweets downloaded so far
# getting tweets before 931234142905348095
# ...1992 tweets downloaded so far
# getting tweets before 902249048580603903
# ...2191 tweets downloaded so far
# getting tweets before 870010758838366207
# ...2390 tweets downloaded so far
# getting tweets before 825032814089248767
# ...2587 tweets downloaded so far
# getting tweets before 802366476606783488
# ...2783 tweets downloaded so far
# getting tweets before 784597479450939393
# ...2982 tweets downloaded so far
# getting tweets before 721402801075519487
# ...3108 tweets downloaded so far
# getting tweets before 147511987696451585
# ...3108 tweets downloaded so far
# writen to file
# RrlwildeWilde
# account 43
# not protected
# getting tweets before 487571616520355840
# ...224 tweets downloaded so far
# getting tweets before 459182771022213119
# ...224 tweets downloaded so far
# writen to file
# RepTimQuinn
# account 44
# not protected
# account inactive
# ChristoffersonK
# account 45
# not protected
# zero tweets
# jonhawkins57
# account 46
# not protected
# getting tweets before 966426228348497920
# ...160 tweets downloaded so far
# writen to file
# DerrinOwens
# account 47
# not protected
# getting tweets before 210055239238299647
# ...37 tweets downloaded so far
# writen to file
# _ValPeterson
# account 48
# not protected
# getting tweets before 161574107207569408
# ...55 tweets downloaded so far
# writen to file
# marshajudkins
# account 49
# not protected
# getting tweets before 972012275740557311
# ...3 tweets downloaded so far
# writen to file
# adamerobertson
# account 50
# not protected
# getting tweets before 260239245900390399
# ...48 tweets downloaded so far
# writen to file
# NormThurston
# account 51
# not protected
# getting tweets before 1025358846938636287
# ...400 tweets downloaded so far
# getting tweets before 843196616425193471
# ...600 tweets downloaded so far
# getting tweets before 725084526578262015
# ...797 tweets downloaded so far
# getting tweets before 663350104431063040
# ...997 tweets downloaded so far
# getting tweets before 648542513733636095
# ...1196 tweets downloaded so far
# getting tweets before 578722854578970623
# ...1396 tweets downloaded so far
# getting tweets before 526937930695065599
# ...1466 tweets downloaded so far
# getting tweets before 439173786584100863
# ...1466 tweets downloaded so far
# writen to file
# votegibson
# account 52
# not protected
# zero tweets
# mikemckellutah
# account 53
# not protected
# getting tweets before 196016310570860544
# ...177 tweets downloaded so far
# writen to file
# RepMarcRoberts
# account 54
# not protected
# getting tweets before 569919697258307583
# ...399 tweets downloaded so far
# getting tweets before 357542604050661376
# ...559 tweets downloaded so far
# getting tweets before 291935656169570303
# ...559 tweets downloaded so far
# writen to file
# RepWatkins
# account 55
# not protected
# getting tweets before 121429568937668608
# ...90 tweets downloaded so far
# writen to file
# cralbrecht52
# account 56
# not protected
# getting tweets before 684765987959345153
# ...3 tweets downloaded so far
# writen to file
# ShippRex
# account 57
# not protected
# account inactive
# phil_lyman
# account 58
# not protected
# getting tweets before 617370370635489279
# ...89 tweets downloaded so far
# writen to file
# lowrysnow
# account 59
# not protected
# getting tweets before 1067799710268710911
# ...400 tweets downloaded so far
# getting tweets before 849404389571923967
# ...599 tweets downloaded so far
# getting tweets before 698157730586955775
# ...736 tweets downloaded so far
# getting tweets before 246389936285159423
# ...736 tweets downloaded so far
# writen to file
# SenatorLuz
# account 60
# not protected
# getting tweets before 1273706296663928831
# ...400 tweets downloaded so far
# getting tweets before 1259959798268739583
# ...600 tweets downloaded so far
# getting tweets before 1246477930554773503
# ...800 tweets downloaded so far
# getting tweets before 1240664148100280321
# ...1000 tweets downloaded so far
# getting tweets before 1232172876419096575
# ...1197 tweets downloaded so far
# getting tweets before 1204835180151656447
# ...1397 tweets downloaded so far
# getting tweets before 1151709285358825472
# ...1597 tweets downloaded so far
# getting tweets before 1111659837761306623
# ...1796 tweets downloaded so far
# getting tweets before 1092500868279291903
# ...1996 tweets downloaded so far
# getting tweets before 1076856699137384447
# ...2196 tweets downloaded so far
# getting tweets before 1060989206061768703
# ...2396 tweets downloaded so far
# getting tweets before 1009833573082226687
# ...2596 tweets downloaded so far
# getting tweets before 981889489067888646
# ...2794 tweets downloaded so far
# getting tweets before 960952409462784004
# ...2992 tweets downloaded so far
# getting tweets before 943655108235030527
# ...3192 tweets downloaded so far
# getting tweets before 928739719957147647
# ...3224 tweets downloaded so far
# getting tweets before 926275776105738239
# ...3224 tweets downloaded so far
# writen to file
# derekkitchen
# account 61
# not protected
# getting tweets before 1283521387752128512
# ...399 tweets downloaded so far
# getting tweets before 1276532220925079553
# ...599 tweets downloaded so far
# getting tweets before 1267141568848228357
# ...798 tweets downloaded so far
# getting tweets before 1242315458696495103
# ...998 tweets downloaded so far
# getting tweets before 1235065240586338303
# ...1196 tweets downloaded so far
# getting tweets before 1220439790547546111
# ...1396 tweets downloaded so far
# getting tweets before 1199548564529012735
# ...1595 tweets downloaded so far
# getting tweets before 1164685305443581954
# ...1794 tweets downloaded so far
# getting tweets before 1092822269351538688
# ...1993 tweets downloaded so far
# getting tweets before 977220784652304383
# ...2189 tweets downloaded so far
# getting tweets before 48070833662459903
# ...2231 tweets downloaded so far
# getting tweets before 7714181911
# ...2231 tweets downloaded so far
# writen to file
# JaniIwamoto
# account 62
# not protected
# getting tweets before 428599083796660223
# ...89 tweets downloaded so far
# writen to file
# KarenMayneUT5
# account 63
# not protected
# getting tweets before 1192902338622545919
# ...400 tweets downloaded so far
# getting tweets before 1043725718247489535
# ...600 tweets downloaded so far
# getting tweets before 936383119489253375
# ...799 tweets downloaded so far
# getting tweets before 836598561051570176
# ...997 tweets downloaded so far
# getting tweets before 695758272536584191
# ...1197 tweets downloaded so far
# getting tweets before 553024609214537727
# ...1319 tweets downloaded so far
# getting tweets before 476855821901365247
# ...1319 tweets downloaded so far
# writen to file
# DeidreHenderson
# account 64
# not protected
# getting tweets before 1262885326843899903
# ...400 tweets downloaded so far
# getting tweets before 1241828838515953663
# ...600 tweets downloaded so far
# getting tweets before 1102684910093971455
# ...799 tweets downloaded so far
# getting tweets before 958027252456767493
# ...999 tweets downloaded so far
# getting tweets before 689812332243910656
# ...1199 tweets downloaded so far
# getting tweets before 575897446250770431
# ...1398 tweets downloaded so far
# getting tweets before 479294350556266495
# ...1597 tweets downloaded so far
# getting tweets before 415528411436572671
# ...1797 tweets downloaded so far
# getting tweets before 357220335633960960
# ...1997 tweets downloaded so far
# getting tweets before 310413126459879425
# ...2197 tweets downloaded so far
# getting tweets before 289742793084133375
# ...2397 tweets downloaded so far
# getting tweets before 168003370622267391
# ...2597 tweets downloaded so far
# getting tweets before 59022518559838207
# ...2797 tweets downloaded so far
# getting tweets before 45149639426576383
# ...2997 tweets downloaded so far
# getting tweets before 16738999984979967
# ...3197 tweets downloaded so far
# getting tweets before 19964627409
# ...3237 tweets downloaded so far
# getting tweets before 18522388419
# ...3237 tweets downloaded so far
# writen to file
# Mskriebe
# account 65
# not protected
# getting tweets before 1280733514896273409
# ...399 tweets downloaded so far
# getting tweets before 1263125785482690560
# ...599 tweets downloaded so far
# getting tweets before 1251555195932139520
# ...798 tweets downloaded so far
# getting tweets before 1240698331556229119
# ...998 tweets downloaded so far
# getting tweets before 1226254256920940543
# ...1198 tweets downloaded so far
# getting tweets before 1219737913908293631
# ...1398 tweets downloaded so far
# getting tweets before 1202451093738774527
# ...1598 tweets downloaded so far
# getting tweets before 1189287092129615872
# ...1798 tweets downloaded so far
# getting tweets before 1175084470539411455
# ...1998 tweets downloaded so far
# getting tweets before 1163658536980582403
# ...2198 tweets downloaded so far
# getting tweets before 1146247227976761345
# ...2398 tweets downloaded so far
# getting tweets before 1110727446926548992
# ...2598 tweets downloaded so far
# getting tweets before 1089209456754188287
# ...2798 tweets downloaded so far
# getting tweets before 1053665057802878975
# ...2997 tweets downloaded so far
# getting tweets before 1019991481497485311
# ...3197 tweets downloaded so far
# getting tweets before 969408338252455935
# ...3200 tweets downloaded so far
# getting tweets before 968720379136172032
# ...3200 tweets downloaded so far
# writen to file
# LincolnFillmore
# account 66
# not protected
# getting tweets before 1001916225532788736
# ...400 tweets downloaded so far
# getting tweets before 877563937008435199
# ...600 tweets downloaded so far
# getting tweets before 687633261565087743
# ...627 tweets downloaded so far
# getting tweets before 666331844187586559
# ...627 tweets downloaded so far
# writen to file
# https://www.google.com/search?client=safari&rls=en&q=Utah+Daniel+McCay&ie=UTF-8&oe=UTF-8
# account 67
# User not found.
# SenThatcher
# account 68
# not protected
# getting tweets before 1106586409429696511
# ...400 tweets downloaded so far
# getting tweets before 964649742671101951
# ...598 tweets downloaded so far
# getting tweets before 814160244175564799
# ...717 tweets downloaded so far
# getting tweets before 312328504148623359
# ...717 tweets downloaded so far
# writen to file
# Political_Jake
# account 69
# not protected
# getting tweets before 1106380887686410239
# ...400 tweets downloaded so far
# getting tweets before 494132994945593343
# ...578 tweets downloaded so far
# getting tweets before 83895429439303679
# ...578 tweets downloaded so far
# writen to file
# danhemmert
# account 70
# not protected
# getting tweets before 12653527826436095
# ...45 tweets downloaded so far
# writen to file
# KeithGroverUT
# account 71
# not protected
# getting tweets before 428691929874710527
# ...65 tweets downloaded so far
# writen to file
# curtbramble
# account 72
# not protected
# getting tweets before 3985758479
# ...152 tweets downloaded so far
# writen to file
# annmillner
# account 73
# not protected
# account inactive
# Sen_Stevenson
# account 74
# not protected
# account inactive
# JStuartAdams
# account 75
# not protected
# getting tweets before 621341760585793536
# ...372 tweets downloaded so far
# getting tweets before 297391469533229055
# ...372 tweets downloaded so far
# writen to file
# gopTODD
# account 76
# not protected
# getting tweets before 1278471854634594303
# ...400 tweets downloaded so far
# getting tweets before 1271308495044788225
# ...600 tweets downloaded so far
# getting tweets before 1261306721231704063
# ...800 tweets downloaded so far
# getting tweets before 1258261416571625471
# ...1000 tweets downloaded so far
# getting tweets before 1254068740536168449
# ...1200 tweets downloaded so far
# getting tweets before 1250229170858164223
# ...1400 tweets downloaded so far
# getting tweets before 1246610624022380545
# ...1600 tweets downloaded so far
# getting tweets before 1243535165504155647
# ...1800 tweets downloaded so far
# getting tweets before 1241748269178318848
# ...2000 tweets downloaded so far
# getting tweets before 1237812826489540607
# ...2200 tweets downloaded so far
# getting tweets before 1233532309221052415
# ...2400 tweets downloaded so far
# getting tweets before 1228356661925969919
# ...2600 tweets downloaded so far
# getting tweets before 1220037700360605695
# ...2800 tweets downloaded so far
# getting tweets before 1214572860078874624
# ...3000 tweets downloaded so far
# getting tweets before 1208151392965185535
# ...3200 tweets downloaded so far
# getting tweets before 1205168757871501311
# ...3250 tweets downloaded so far
# getting tweets before 1204149293822595076
# ...3250 tweets downloaded so far
# writen to file
# RalphOkerlund
# account 77
# not protected
# account inactive
# SenLyleHillyard
# account 78
# not protected
# getting tweets before 1202794122181894143
# ...399 tweets downloaded so far
# getting tweets before 1141764016731115520
# ...597 tweets downloaded so far
# getting tweets before 1080320660314832895
# ...797 tweets downloaded so far
# getting tweets before 1027616348178767871
# ...995 tweets downloaded so far
# getting tweets before 981160334638526465
# ...1194 tweets downloaded so far
# getting tweets before 928471763343753215
# ...1394 tweets downloaded so far
# getting tweets before 842817452333580288
# ...1593 tweets downloaded so far
# getting tweets before 784024057482141695
# ...1793 tweets downloaded so far
# getting tweets before 735851371941896191
# ...1993 tweets downloaded so far
# getting tweets before 675708006827343872
# ...2193 tweets downloaded so far
# getting tweets before 628597859374362623
# ...2393 tweets downloaded so far
# getting tweets before 572527879201808383
# ...2593 tweets downloaded so far
# getting tweets before 551171734498312191
# ...2793 tweets downloaded so far
# getting tweets before 514440650079498239
# ...2993 tweets downloaded so far
# getting tweets before 492671826095398911
# ...3193 tweets downloaded so far
# getting tweets before 461979132843139071
# ...3215 tweets downloaded so far
# getting tweets before 459427337096806399
# ...3215 tweets downloaded so far
# writen to file
# HinkinsIems
# account 79
# not protected
# account inactive
# DonnieIpson
# account 80
# not protected
# getting tweets before 915432026995531775
# ...317 tweets downloaded so far
# getting tweets before 298752808998563839
# ...317 tweets downloaded so far
# writen to file

# %%
# list with secondary handles 
handles_2 = df.loc[df.handle_2.isnull()==False, 'handle_2']
# reset index 
handles_2 = handles_2.reset_index(drop=True)

len(handles_2)
# Out:
# 0

# %%
handles_2
# Out:
# Series([], Name: handle_2, dtype: float64)

# %%
# collect tweets from secondary handles 
for handle in handles_2:
    print(handle)
    get_timeline(handle, state_name)

# %%
# After running the get_timeline() function find the metadata file 
meta_data = glob.glob('*metadata*.csv')[0]
print(meta_data)
# Out:
# Texas_metadata_August05.csv

# %%
# Find all active accounts
meta_file = pd.read_csv(meta_data, header=None)

active_accounts = meta_file[meta_file[7]=='active'][0]

# reset index 
active_accounts = active_accounts.reset_index(drop=True)

# %%
retry_accounts = [x for x in handles_1.to_list() if x not in meta_file[0].to_list()]

len(retry_accounts)
# Out:
# 0

# %%
# check how many accounts are there 
len(active_accounts)
# Out:
# 156

# %%
# collect friends 

len(active_accounts)
for account in active_accounts:
    print(account)
    get_friend_ids(account)
# Out:
# GaryVanDeaver
# Dan_Flynn
# CBellJr
# ColeHefnerTX
# RepMattSchaefer
# jdeantexas
# CodyforTexas
# chrispaddie
# wrayfortexas
# travisfortexas
# KyleKacal
# BenLemanTX
# RaneyForTexas
# Toth_4_Texas
# Rate limit reached. Sleeping for: 895
# willmetcalfTX
# JCyrier
# Bailesfortx
# James_E_White
# DadePhelan
# RepJoeDeshotel
# mayes_middleton
# DrGregBonnen
# RepDennisBonnen
# ronereynolds
# GatesforTexas
# RepEdThompson
# RyanGuillen
# Rate limit reached. Sleeping for: 895
# Failed to send request: ('Connection aborted.', OSError("(54, 'ECONNRESET')"))
# toddahunter
# justinaholland
# RepAbelHerrero
# RepLongoria
# AlexForTexas_
# EddieLucioIII
# andoconmando39
# TerryCanales40
# RDBobbyGuerra
# ErinForYall
# SherylCole1
# VikkiGoodwinTX
# DonnaHowardTX
# GinaForAustin
# CeliaIsrael
# EddieforTexas
# Rate limit reached. Sleeping for: 895
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-301271f6d272> in <module>
#       4 for account in active_accounts:
#       5     print(account)
# ----> 6     get_friend_ids(account)
#       7
#       8
#
# <ipython-input-116-7e5270ee203c> in get_friend_ids(screen_name)
#      16         friendsids =[]
#      17
# ---> 18         for user in tweepy.Cursor(api.friends_ids, screen_name= screen_name,count=5000).items():
#      19             friendsids.append(user)
#      20
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#      71         data, cursors = self.method(cursor=self.next_cursor,
#      72                                     *self.args,
# ---> 73                                     **self.kargs)
#      74         self.prev_cursor, self.next_cursor = cursors
#      75         if len(data) == 0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
# Retry accounts for which friends were not successfully collected  

# Accounts for which friend Ids were successfully collected
filepath_friends = glob.glob('*/*FriendsIds*.csv')

if len(filepath_friends) > 0:
    scarpe_friends = [name.split('/')[0] for name in filepath_friends]

    # Accounts for which to retry collection 
    retry_friends = [x for x in active_accounts if x not in scarpe_friends]  
    print('Retry %s accounts' %(len(retry_friends)))

    while len(retry_friends) > 0:
        for account in retry_friends:
            print(account)
            get_friend_ids(account)

        filepath_friends = glob.glob('*/*FriendsIds*.csv')
        scarped_friends = [name.split('/')[0] for name in filepath_friends]
        retry_friends = [x for x in active_accounts if x not in scarped_friends]
        print('Retry %s accounts' %(len(retry_friends)))
# Out:
# Retry 115 accounts
# RyanGuillen
# Rate limit reached. Sleeping for: 303
# EddieforTexas
# jamestalarico
# BradBuckleyDVM
# TrentAshbyTX
# BurnsForTexas
# dr_sheffield
# RepMikeLang
# PhilKingTX
# Reggie4Tx
# tparker63
# RepLynnStucky
# ForHD65
# MattShaheen
# leachfortexas
# Rate limit reached. Sleeping for: 894
# DrewSpringer
# RepJamesFrank
# Scott_SanfordTX
# RepStanLambert
# DrewDarbyTX
# KyleBiedermann
# poncho_nevarez
# RepMaryGonzalez
# CesarJBlanco
# lina4texas
# moodyforelpaso
# ArtFierro79
# BrooksLandgraf
# Burrows4TX
# FrulloForTexas
# Rate limit reached. Sleeping for: 895
# FourPriceTX
# KingForTexas
# CandyNobleHD89
# RepRamonRomero
# StephanieKlick
# RepStickland
# RepMattKrause
# reptinderholt
# NicoleCollier95
# Bill_Zedler
# GoldmanCraig
# VoteGiovanni
# charliegeren
# LorraineForTX
# ChrisGTurner
# Rate limit reached. Sleeping for: 895
# Ramos4Texas
# RafaelAnchia
# jessicafortexas
# TerryforTexas
# JaredLPatterson
# Victoria4Texas
# MorganMeyerTX
# helengiddings
# RepToniRoseTX
# AngieChenButton
# RhettaForHD113
# TurnerForTX
# juliejohnsonTX
# TMFtx
# Rate limit reached. Sleeping for: 895
# CortezPhilip
# PachecoForTexas
# RolandForTexas
# stevefortx
# RepLyleLarson
# DiegoBernalTX
# vote4ina
# raylopezfortx
# SamHarless126
# DanHuberty
# BriscoeCain
# DennisPaul129
# TomOliverson
# gina_calanni
# Rate limit reached. Sleeping for: 895

# %%
#CheckFind duplicates     
# from collections import Counter
#[k for k,v in Counter(scarped_accounts).items() if v>1]
#print(len(retry_friends))

# %%
# Get followers of active accounts 
for account in active_accounts:
        print(account)
        get_follower_ids(account)
# Out:
# JoelMFerry
# JeffersonMoss
# vpottercache
# djohnsonhouse4
# cory_maloy
# WaldripSteve
# KellyMiles4Utah
# Paul_Ray
# StephenHandyUT
# timothyhawkes
# raywardutah
# SueDuckworthUT
# jenforutah
# RepBriscoe
# RepAngelaRomero
# Rate limit reached. Sleeping for: 890
# RepBrianKing
# mike_winder
# RepEWeight
# VoteSuz
# hcraighall
# RepKarenKwan
# RepMarkwheatley
# RepPatriceArent
# RepCarolMoss
# erickhutchings
# RepJimDunnigan
# steph_pitcher
# writerathome
# RepAStoddard
# Rate limit reached. Sleeping for: 894
# RepMariePoulson
# KenIvoryUT
# SpendloveRobert
# JeffStenquist
# CandicePierucci
# RrlwildeWilde
# jonhawkins57
# DerrinOwens
# _ValPeterson
# marshajudkins
# adamerobertson
# NormThurston
# mikemckellutah
# RepMarcRoberts
# RepWatkins
# Rate limit reached. Sleeping for: 893
# cralbrecht52
# phil_lyman
# lowrysnow
# SenatorLuz
# derekkitchen
# JaniIwamoto
# KarenMayneUT5
# DeidreHenderson
# Mskriebe
# LincolnFillmore
# SenThatcher
# Political_Jake
# danhemmert
# KeithGroverUT
# Rate limit reached. Sleeping for: 894
# curtbramble
# JStuartAdams
# gopTODD
# SenLyleHillyard
# DonnieIpson

# %%
# Retry accounts for which followers were not successfully collected  

# Accounts for which follower Ids were successfully collected
filepath_followers = glob.glob('*/*FollowerIds*.csv')

if len(filepath_followers) > 0:
    scarped_followers = [name.split('/')[0] for name in filepath_followers]

     # Accounts for which to retry collection  
    retry_followers = [x for x in active_accounts if x not in scarped_followers]  
    print('Retry %s accounts' %(len(retry_followers)))

    while len(retry_followers) > 0:
        for account in retry_followers:
            print(account)
            get_follower_ids(account)

        filepath_followers = glob.glob('*/*FollowerIds*.csv')
        scarped_followers = [name.split('/')[0] for name in filepath_followers]
        retry_followers = [x for x in active_accounts if x not in scarped_followers]
        print('Retry %s accounts' %(len(retry_followers)))
        
    print('All followers collected')
    
    
        

# #Find duplicates     
# #from collections import Counter
# #[k for k,v in Counter(scarped_followers).items() if v>1]
# #len(retry_followers)

# %%
# check number of tweets scraped 
tl = glob.glob('*/*_Tweets_*')
len(tl)
# Out:
# 63

# %%
# check number of followers scraped 
tf = glob.glob('*/*_FollowerIds_*')
len(tf)
# Out:
# 63

# %%
# check number of friends scraped 
tfr = glob.glob('*/*_FriendsIds_*')
len(tfr)
# Out:
# 63
